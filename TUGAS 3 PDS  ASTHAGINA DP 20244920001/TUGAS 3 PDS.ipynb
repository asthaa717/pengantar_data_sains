# %% [markdown]
# # TUTORIAL MEMBUAT PETA (SHPFILE) DI PYTHON

# %% [markdown]
# Data diperoleh dari publikasi BPS Kab. Tangerang dengan judul Kabupaten Tangerang dalam Angka 2024 dan data yang digunakan adalah data luas daerah dan jumlah pulau menurut kecamatan di Kabupaten Tangerang 2023.
#
# note: data mengalami sedikit pengeditan karena diperlukan titik koordinat

# %% [markdown]
# Langkah 1:
# menyiapkan package dan data yang akan digunakan diantaranya:
# - Geopandas: spasial + geopandas, dimana package ini dapat membaca dan menulis file spasial
# - matplotlib: library visualisasi dasar untuk membuat visualisasi grafik
# - folium: membuat peta interaktif yang mirip dengan mapview dan leaflet pada R
# - branca: pustaka pendukung folium
# - data shapefile yang sudah dibuat melalui Rstudio
#
# Dalam membuat peta menggunakan jupyter nb ini saya tidak membuat file shapefile dari awal karena data yang digunakan di dalamnya masih sama yaitu Luas daerah dan jumlah pulau di kabupaten tangerang 2023.

# %% [markdown]
# Langkah 2: Mengimpor file shapefile
#
# impor shapefile dilakukan agar kode dapat membaca data yang akan dibuat menjadi sebuah peta

# %%
import geopandas as gpd

shp = gpd.read_file("D:/tugas/Letak Kecamatan di Kabupaten Tangerang.shp")
shp
# Out:
#           Kecamtn  LsWlKm2  PrsntLW                  geometry
# 0          Cisoka    31.21     3.02  POINT (106.4052 -6.2614)
# 1          Solear    34.07     3.29   POINT (106.4229 -6.307)
# 2       Tigaraksa    55.30     5.35  POINT (106.4837 -6.2618)
# 3           Jambe    28.25     2.73  POINT (106.4935 -6.3252)
# 4          Cikupa    46.00     4.45  POINT (106.5043 -6.2434)
# 5        Panongan    36.15     3.49   POINT (106.523 -6.2577)
# 6           Curug    30.83     2.98  POINT (106.5701 -6.2357)
# 7      Kelapa Dua    26.22     2.53  POINT (106.6143 -6.2467)
# 8           Legok    37.28     3.60  POINT (106.5701 -6.2971)
# 9      Pagedangan    50.75     4.91  POINT (106.6173 -6.2956)
# 10         Cisauk    30.05     2.90   POINT (106.635 -6.3411)
# 11     Pasarkemis    30.73     2.97  POINT (106.5513 -6.1591)
# 12   Sindang Jaya    41.39     4.00  POINT (106.5333 -6.1931)
# 13       Balaraja    32.30     3.12  POINT (106.4464 -6.2038)
# ...

# %% [markdown]
# Langkah 3: Mengimpor package yang akan digunakan untuk membuat peta
#
# impor package yang akan digunakann untuk menampilkan peta interaktif, diantaranya adalah matplotlib, branca, dan folium. ketiga package tersebut adalah package yang digunakan untuk menampilkan peta interaktif dari shpaefile yang sebelumnya sudah di baca oleh fungsi geopandas.

# %%
import matplotlib as plt
import branca as bc
import folium
shp.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# titik-titik biru di atas menunjukkan letak, luas daerah, dan presentase setiap kecamatan yang ada di kabupaten tangerang.

# %% [markdown]
# ### Referensi
#
# 1. https://youtu.be/xxg4Vm-Xg9g?si=BUJWU368RZTmuApV
# 2. https://youtu.be/_xeoUYUO8Lo?si=wR4AajeUTHUVv7Q5
